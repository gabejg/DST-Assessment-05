# %% [markdown]
# Pre-req:

# %%
import findspark
findspark.init()

import datetime
import pickle
from urllib.request import urlopen
import os
import pandas as pd
import numpy as np
import gensim
import pickle
import matplotlib.pyplot as plt
import pyspark

import heapq

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Galeforse/DST-Assessment-05/main/Data/NCSC%20Reports.csv')

# %%
print("shape:"+str(np.shape(df)))
df.head()
# Out:
# shape:(221, 5)
#    Unnamed: 0            Title  \
# 0           0  23rd April 2021
# 1           1  16th April 2021
# 2           2  12th April 2021
# 3           3   2nd April 2021
# 4           4  26th March 2021
#
#                                              Article  \
# 0  ['The NCSC is aware that a malicious piece of ...
# 1  ['Cyber security researchers have uncovered a ...
# 2  ['Cyber security researchers, Esentire, have w...
# 3  ['The UK education sector continues to face an...
# 4  ['Earlier this month Microsoft confirmed that ...
#
#                                               topics  \
# 0  ['Cyber attack', 'Cyber strategy', 'Education'...
# 1  ['Cyber strategy', 'Patching', 'Vulnerabilities']
# 2  ['Phishing', 'Social media', 'Personal data', ...
# 3  ['Education', 'Incident management', 'Secure d...
# 4  ['Cyber attack', 'Education', 'Mitigation', 'P...
#
#                                                Links
# 0  https://www.ncsc.gov.uk/report/weekly-threat-r...
# 1  https://www.ncsc.gov.uk/report/weekly-threat-r...
# 2  https://www.ncsc.gov.uk/report/weekly-threat-r...
# 3  https://www.ncsc.gov.uk/report/weekly-threat-r...
# 4  https://www.ncsc.gov.uk/report/weekly-threat-r...

# %%
df.iloc[67,2]
# Out:
# "['The government has issued a cyber security alert to charities warning them of a spike in the number of criminals trying to access and change the private information of staff.\\nThe Charity Commission has received several reports from charities that have been targeted by fraudsters impersonating HR staff members, specifically attempting to change employees bank details. In all cases, the request was made through an email.\\nCharities should look out for email requests from spoofed or similar email addresses to their legitimate HR departments, finance departments or staff with authority to change bank details. The NCSC has provided guidance which can help with this.\\nLike most businesses, charities are increasingly reliant on computer technology and are at risk of falling victim to cyber criminals. The NCSC has published guidance on how to improve cyber security within a charity with the collection including specific phishing advice.', 'With Christmas shopping well underway, this week consumer association Which? revealed it had found “serious security flaws” in some children’s smart toys.\\nWorking with cyber security specialists, Which? raised concerns about some connected toys sold by major retailers, claiming that they lacked basic cyber security measures and were vulnerable to attack.\\n\\nThis investigation highlights the importance for manufacturers of internet connected devices to take every measure to ensure their products are safe to use.\\nEarlier this year the NCSC supported a DCMS consultation on regulatory proposals for consumer Internet of Things, which would create a minimum baseline for security requirements in smart devices.\\nWhich? has outlined five tips to help when buying and using smart toys:\\nRead the description of the connected toy carefully in the shop or online. Find out what the toy actually does and how your child will interact with it.\\nSearch online to see if there have been any security concerns raised about the toy previously, such as a leak of personal data. If you are at all concerned, consider a non-smart toy instead.\\nIf you do buy a smart toy, submit only the minimal amount of personal data required when setting up an account for your child. So, not too much data is exposed if things do go wrong. Do set strong passwords, though, to ensure any accounts are properly protected.\\nKeep an eye on your child when they’re playing with the smart toy, particularly if it can send or receive messages.\\nWhen your child is not playing with the smart toy, make sure you turn it off completely.\\nNCSC guidance on how to secure internet connected devices in the home is available.']"

# %%
df.iloc[67,3]
# Out:
# "['Cyber threat']"

# %%
from pyspark.ml.clustering import LDA

# %%
from pyspark.sql import SparkSession

spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://Gabriel-PC.Home:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Python Spark SQL basic example</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
type(spark)
# Out:
# pyspark.sql.session.SparkSession

# %%
dfs = spark.read.load("NCSC Reports.csv",format='csv', header = "true")

# %%
type(dfs)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
dfs.printSchema()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- Unnamed: 0: string (nullable = true)
#  |-- Title: string (nullable = true)
#  |-- Article: string (nullable = true)
#  |-- topics: string (nullable = true)
#  |-- Links: string (nullable = true)

# %%
from pyspark import SparkContext
sc = SparkContext("local", "first app")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-5fadacfde14b> in <module>
#       1 from pyspark import SparkContext
# ----> 2 sc = SparkContext("local", "first app")
#
# C:\Spark\spark-3.1.1-bin-hadoop2.7\python\pyspark\context.py in __init__(self, master, appName, sparkHome, pyFiles, environment, batchSize, serializer, conf, gateway, jsc, profiler_cls)
#     142                 " is not allowed as it is a security risk.")
#     143
# --> 144         SparkContext._ensure_initialized(self, gateway=gateway, conf=conf)
#     145         try:
#     146             self._do_init(master, appName, sparkHome, pyFiles, environment, batchSize, serializer,
#
# C:\Spark\spark-3.1.1-bin-hadoop2.7\python\pyspark\context.py in _ensure_initialized(cls, instance, gateway, conf)
#     340
#     341                     # Raise error if there is already a running Spark context
# --> 342                     raise ValueError(
#     343                         "Cannot run multiple SparkContexts at once; "
#     344                         "existing SparkContext(app=%s, master=%s)"
#
# ValueError: Cannot run multiple SparkContexts at once; existing SparkContext(app=Python Spark SQL basic example, master=local[*]) created by getOrCreate at <ipython-input-7-a990e23b682e>:3

# %%
#df2 = spark.read.load("Data/NCSC Reports.csv",
#                     format="csv", sep=";", inferSchema="true", header="true")

# %%
#df3 = pickle.load(open('wordlist.p','rb'))

# %%
#type(df3)
# Out:
# list

# %%
from sparknlp.base import Finisher, DocumentAssembler
from sparknlp.annotator import (Tokenizer, Normalizer,
                                Lemmatizer, LemmatizerModel, StopWordsCleaner)
from pyspark.ml import Pipeline

# %%
import sparknlp
sparknlp = sparknlp.start()

# %%
import nltk
from nltk.corpus import stopwords
from nltk.corpus import words

# %%
eng_stopwords = stopwords.words('english')
eng_words = words.words()

# %%
import pickle
from urllib.request import urlopen

x = urlopen("https://github.com/Galeforse/DST-Assessment-05/raw/main/Data/TF_IDF_by_date.p")
tf_idf_date = pickle.load(x)

x = urlopen("https://github.com/Galeforse/DST-Assessment-05/raw/main/Data/Report_counts_dict.p")
counts = pickle.load(x)

# %%
type(tf_idf_date)
# Out:
# dict

# %%
type(counts)
# Out:
# dict

# %%
items = list(counts.items())[:5]
items
# Out:
# [('23rd April 2021',
#   {'ncsc': 3,
#    'brands': 1,
#    'spyware': 2,
#    'pcs': 3,
#    'earlier': 1,
#    'impacted': 1,
#    'experts': 1,
#    'apt': 1,
#    'android': 1,
#    'university': 2,
#    'organisations': 1,
#    'asking': 1,
#    'code': 1,
#    'suspiciouslooking': 1,
#    'using': 1,
#    'vpn': 2,
#    'whilst': 1,
#    'agency': 1,
#    'gain': 1,
#    'guidance': 2,
#    'remain': 1,
#    'criminals': 3,
#    'security': 2,
#    'recently': 2,
#    'education': 2,
#    'appliancesnour': 1,
#    'example': 1,
#    'offline': 2,
#    'breachednseparately': 1,
#    'response': 1,
#    'attacks': 1,
#    'infrastructure': 1,
#    'receives': 1,
#    'uk': 1,
#    'dhs': 1,
#    'systemsnthe': 1,
#    'direct': 1,
#    'saying': 1,
#    'evidence': 1,
#    'flubot': 2,
#    'messages': 1,
#    'urged': 1,
#    'unauthenticated': 1,
#    'continues': 1,
#    'portsmouths': 1,
#    'homeland': 1,
#    'partners': 1,
#    'uknthe': 1,
#    'package': 1,
#    'cisa': 1,
#    'scenarios': 1,
#    'victim': 1,
#    'attacknthe': 1,
#    'actively': 1,
#    'network': 1,
#    'campaign': 1,
#    'familiarise': 2,
#    'aware': 2,
#    'target': 1,
#    'missed': 1,
#    'execution': 1,
#    'directive': 1,
#    'following': 1,
#    'follows': 1,
#    'rehearse': 1,
#    'app': 1,
#    'securitys': 1,
#    'appliancesnit': 1,
#    'emergency': 1,
#    'thisnandroid': 1,
#    'media': 1,
#    'deliverynscammers': 1,
#    'exploiting': 1,
#    'forwarded': 1,
#    'investigate': 1,
#    'secure': 3,
#    'customers': 1,
#    'across': 1,
#    'pulse': 4,
#    'due': 1,
#    'devices': 1,
#    'ransomware': 1,
#    'cvenwe': 1,
#    'exploit': 2,
#    'malicious': 1,
#    'cyber': 5,
#    'week': 1,
#    'behaviour': 1,
#    'piece': 1,
#    'plan': 1,
#    'encourage': 1,
#    'work': 1,
#    'advice': 1,
#    'higher': 1,
#    'department': 1,
#    'ncscs': 1,
#    'known': 1,
#    'actors': 1,
#    'vigilant': 1,
#    'appliancesnthe': 1,
#    'website': 1,
#    'personal': 1,
#    'installed': 1,
#    'update': 1,
#    'continue': 1,
#    'tracking': 1,
#    'blog': 1,
#    'systems': 2,
#    'issue': 1,
#    'incident': 1,
#    'mitigating': 1,
#    'connect': 3,
#    'prime': 1,
#    'users': 1,
#    'discovered': 1,
#    'install': 1,
#    'wellknown': 1,
#    'limited': 1,
#    'restore': 1,
#    'published': 4,
#    'fireeye': 1,
#    'text': 2,
#    'malware': 1,
#    'regularly': 1,
#    'r': 1,
#    'event': 1,
#    'affecting': 2,
#    'phones': 1,
#    'says': 1,
#    'sector': 2,
#    'message': 1,
#    'trusted': 1,
#    'number': 1,
#    'remote': 1,
#    'alert': 2,
#    'posted': 1,
#    'appealing': 1,
#    'vulnerabilities': 1,
#    'vulnerability': 1,
#    'defences': 1,
#    'international': 1,
#    'cybersecurity': 1,
#    'also': 1,
#    'experienced': 1,
#    'version': 1,
#    'reported': 1,
#    'defenders': 1,
#    'securely': 1,
#    'urge': 0,
#    'herenformer': 0,
#    'industriesnthe': 0,
#    'settings': 0,
#    'forensic': 0,
#    'policymaking': 0,
#    'incidents': 0,
#    'reviews': 0,
#    'securenfrom': 0,
#    'issues': 0,
#    'fbis': 0,
#    'usefulndefending': 0,
#    'hat': 0,
#    'servicenthe': 0,
#    'agreement': 0,
#    'chip': 0,
#    'bruteforce': 0,
#    'strobe': 0,
#    'limitations': 0,
#    'msn': 0,
#    'statement': 0,
#    'storage': 0,
#    'illegitimately': 0,
#    'magecarts': 0,
#    'capitalise': 0,
#    'obsolete': 0,
#    'filed': 0,
#    'sweden': 0,
#    'right': 0,
#    'hns': 0,
#    'increasensocial': 0,
#    'notifications': 0,
#    'permissions': 0,
#    'distributes': 0,
#    'nany': 0,
#    'conductednindia': 0,
#    'workaround': 0,
#    'worrying': 0,
#    'depend': 0,
#    'discountnearlier': 0,
#    'asavie': 0,
#    'devicesnhns': 0,
#    'concernsnretailer': 0,
#    'whereby': 0,
#    'taking': 0,
#    'passed': 0,
#    'fin': 0,
#    'lucrative': 0,
#    'binary': 0,
#    'periphery': 0,
#    'apologised': 0,
#    'fixednthe': 0,
#    'updatesnthe': 0,
#    'celebrity': 0,
#    'undermines': 0,
#    'active': 0,
#    'devicesnthe': 0,
#    'memory': 0,
#    'strategically': 0,
#    'kitnhowever': 0,
#    'decryption': 0,
#    'suffered': 0,
#    'outcomesnfor': 0,
#    'unannounced': 0,
#    'banks': 0,
#    'servicesnsources': 0,
#    'forthcoming': 0,
#    'popular': 0,
#    'dont': 0,
#    'april': 0,
#    'managernduring': 0,
#    'disguising': 0,
#    'implementing': 0,
#    'u': 0,
#    'quietly': 0,
#    'overnight': 0,
#    'devicenthis': 0,
#    'entry': 0,
#    'attachment': 0,
#    'study': 0,
#    'utterly': 0,
#    'escape': 0,
#    'hackingnvulnerability': 0,
#    'versionna': 0,
#    'stuntman': 0,
#    'accountsnnnintendo': 0,
#    'improved': 0,
#    'brandnew': 0,
#    'craft': 0,
#    'harnessing': 0,
#    'athletes': 0,
#    'carry': 0,
#    'open': 0,
#    'agencies': 0,
#    'bugsnsymantec': 0,
#    'aid': 0,
#    'beufreported': 0,
#    'viewing': 0,
#    'mysql': 0,
#    'pewdiepie': 0,
#    'earliernthe': 0,
#    'impersonate': 0,
#    'interfax': 0,
#    'status': 0,
#    'updated': 0,
#    'servicenthere': 0,
#    'respectively': 0,
#    'breachn': 0,
#    'publishes': 0,
#    'neglect': 0,
#    'finansowego': 0,
#    'komisja': 0,
#    'blockchain': 0,
#    'loss': 0,
#    'checkout': 0,
#    'prosecutors': 0,
#    'npassword': 0,
#    'notable': 0,
#    'generate': 0,
#    'lose': 0,
#    'fixesnany': 0,
#    'categorises': 0,
#    'detectionevasion': 0,
#    'ncscncryptomining': 0,
#    'controversynswedens': 0,
#    'exfiltration': 0,
#    'pleads': 0,
#    'circulating': 0,
#    'standardcompliant': 0,
#    'coldfusion': 0,
#    'beijingnmicrosoft': 0,
#    'launch': 0,
#    'indexed': 0,
#    'estimate': 0,
#    'perl': 0,
#    'neo': 0,
#    'gwr': 0,
#    'netlogon': 0,
#    'chancellor': 0,
#    'verification': 0,
#    'ecsepa': 0,
#    'ostensibly': 0,
#    'optimised': 0,
#    'rtf': 0,
#    'stressed': 0,
#    'numbersnthe': 0,
#    'safenchallenge': 0,
#    'affiliating': 0,
#    'delays': 0,
#    'italy': 0,
#    'possiblennthe': 0,
#    'recklessly': 0,
#    'subscription': 0,
#    'linkedin': 0,
#    'figuresnthe': 0,
#    'angus': 0,
#    'fixingnwhile': 0,
#    'apples': 0,
#    'nnthe': 0,
#    'outcome': 0,
#    'rescue': 0,
#    'roughly': 0,
#    'requestnimpersonation': 0,
#    'linknryuk': 0,
#    'port': 0,
#    'watchdog': 0,
#    'california': 0,
#    'sophistication': 0,
#    'poland': 0,
#    'large': 0,
#    'graphic': 0,
#    'jailed': 0,
#    'tested': 0,
#    'exfiltrated': 0,
#    'setup': 0,
#    'area': 0,
#    'respondents': 0,
#    'worryingly': 0,
#    'internetenabled': 0,
#    'gates': 0,
#    'frozen': 0,
#    'consequence': 0,
#    'websites': 0,
#    'sentry': 0,
#    'practice': 0,
#    'cycon': 0,
#    'nthese': 0,
#    'ot': 0,
#    'photocopiers': 0,
#    'type': 0,
#    'leverages': 0,
#    'operationsnthe': 0,
#    'nwhile': 0,
#    'helpfully': 0,
#    'outsourcing': 0,
#    'tool': 0,
#    'space': 0,
#    'combinedninsurers': 0,
#    'prioritynthe': 0,
#    'wed': 0,
#    'generation': 0,
#    'sort': 0,
#    'yearna': 0,
#    'theyre': 0,
#    'capability': 0,
#    'prompt': 0,
#    'nthis': 0,
#    'civil': 0,
#    'world': 0,
#    'purposesnthe': 0,
#    'contracts': 0,
#    'emergence': 0,
#    'government': 0,
#    'centrenfebruary': 0,
#    'pandemicnhowever': 0,
#    'boarding': 0,
#    'postnthe': 0,
#    'file': 0,
#    'cyberuk': 0,
#    'activitynmalware': 0,
#    'deliberate': 0,
#    'result': 0,
#    'spam': 0,
#    'reminder': 0,
#    'indeed': 0,
#    'martin': 0,
#    'empowering': 0,
#    'overlord': 0,
#    'containing': 0,
#    'stored': 0,
#    'graham': 0,
#    'responsenragnar': 0,
#    'lowquality': 0,
#    'controllers': 0,
#    'sheraton': 0,
#    'figures': 0,
#    'reparationnorganisations': 0,
#    'authored': 0,
#    'compromisena': 0,
#    'grow': 0,
#    'jpeg': 0,
#    'thing': 0,
#    'onlinenadvice': 0,
#    'pdf': 0,
#    'traditional': 0,
#    'minimum': 0,
#    'discovery': 0,
#    'start': 0,
#    'collect': 0,
#    'disruptionnthe': 0,
#    'microsoft': 0,
#    'domains': 0,
#    'singlesign': 0,
#    'conducing': 0,
#    'scheme': 0,
#    'confiscated': 0,
#    'newernthe': 0,
#    'unavailable': 0,
#    'mexicos': 0,
#    'ndigital': 0,
#    'socially': 0,
#    'icedovethunderbird': 0,
#    'exchange': 0,
#    'cited': 0,
#    'highlights': 0,
#    'informationnan': 0,
#    'bundled': 0,
#    'taiwanbased': 0,
#    'anticipate': 0,
#    'attackednon': 0,
#    'sporting': 0,
#    'content': 0,
#    'holidays': 0,
#    'happening': 0,
#    'tvnus': 0,
#    'qbot': 0,
#    'sums': 0,
#    'agencyufencourages': 0,
#    'sticks': 0,
#    'exciting': 0,
#    'deleting': 0,
#    'interests': 0,
#    'prepare': 0,
#    'overview': 0,
#    'securitynequifax': 0,
#    'enterprise': 0,
#    'accountinternetcomputer': 0,
#    'travelling': 0,
#    'expired': 0,
#    'profited': 0,
#    'ceases': 0,
#    'intact': 0,
#    'purported': 0,
#    'enumeration': 0,
#    'federation': 0,
#    'subscribers': 0,
#    'bring': 0,
#    'opportunity': 0,
#    'accountsnadvice': 0,
#    'credit': 0,
#    'diseases': 0,
#    'unauthorized': 0,
#    'leaves': 0,
#    'failings': 0,
#    'equivalent': 0,
#    'screens': 0,
#    'inevitable': 0,
#    'deliveries': 0,
#    'sends': 0,
#    'attacksnover': 0,
#    'controllersnthere': 0,
#    'six': 0,
#    'crimesnthis': 0,
#    'harvesting': 0,
#    'pixelsnthere': 0,
#    'earliest': 0,
#    'threatsnthe': 0,
#    'trickbot': 0,
#    'confirm': 0,
#    'consumers': 0,
#    'stuffing': 0,
#    'ncriminals': 0,
#    'addressed': 0,
#    'analysis': 0,
#    'extreme': 0,
#    'emailsnaction': 0,
#    'discreet': 0,
#    'build': 0,
#    'spoofed': 0,
#    'vietnam': 0,
#    'panic': 0,
#    'phishingnnnew': 0,
#    'onlinenthe': 0,
#    'wellmess': 0,
#    'frauds': 0,
#    'safeguardsnts': 0,
#    'highlight': 0,
#    'corruption': 0,
#    'running': 0,
#    'claimed': 0,
#    'reminds': 0,
#    'sitenmicrosoft': 0,
#    'regarding': 0,
#    'compromising': 0,
#    'impactncryptocurrencies': 0,
#    'reading': 0,
#    'zendesk': 0,
#    'immediatelynmore': 0,
#    'apply': 0,
#    'qemu': 0,
#    'estatenfurther': 0,
#    'localisation': 0,
#    'onto': 0,
#    'neven': 0,
#    'releasednwe': 0,
#    'executionnibm': 0,
#    'student': 0,
#    'year': 0,
#    'ombudsman': 0,
#    'thanks': 0,
#    'groups': 0,
#    'sensitive': 0,
#    'clinic': 0,
#    'fundamental': 0,
#    'credentialsnelsewhere': 0,
#    'buckets': 0,
#    'even': 0,
#    'evaluating': 0,
#    'swipe': 0,
#    'addressninterestingly': 0,
#    'introduction': 0,
#    'founded': 0,
#    'educations': 0,
#    'sectorsnthe': 0,
#    'ndnthe': 0,
#    'rises': 0,
#    'investigated': 0,
#    'nour': 0,
#    'squad': 0,
#    'record': 0,
#    'callsnthe': 0,
#    'well': 0,
#    'yearround': 0,
#    'theftnuscert': 0,
#    'aims': 0,
#    'creates': 0,
#    'standard': 0,
#    'chineseaffiliated': 0,
#    'recommended': 0,
#    'scamsnnphishing': 0,
#    'identifiedndue': 0,
#    'commitment': 0,
#    'attempting': 0,
#    'everyday': 0,
#    'meltdown': 0,
#    'checked': 0,
#    'style': 0,
#    'customersnantitheft': 0,
#    'requests': 0,
#    'brand': 0,
#    'thisnwhile': 0,
#    'usdnfeibs': 0,
#    'remained': 0,
#    'store': 0,
#    'unfixed': 0,
#    'gaining': 0,
#    'underwent': 0,
#    'judgement': 0,
#    'remerged': 0,
#    'scale': 0,
#    'practicablenas': 0,
#    'movementsnfrom': 0,
#    'rnwindows': 0,
#    'acknowledging': 0,
#    'selectednyou': 0,
#    'change': 0,
#    'enhance': 0,
#    'zdnet': 0,
#    'guidensmall': 0,
#    'mail': 0,
#    'review': 0,
#    'establishment': 0,
#    'pwc': 0,
#    'understood': 0,
#    'litigation': 0,
#    'engagement': 0,
#    'earned': 0,
#    'rafotecs': 0,
#    'seeking': 0,
#    'pandemicnnthe': 0,
#    'coronavirusrelated': 0,
#    'cybereason': 0,
#    'investors': 0,
#    'toyotas': 0,
#    'roughtedrelated': 0,
#    'managed': 0,
#    'commissioner': 0,
#    'blaming': 0,
#    'terabits': 0,
#    'smb': 0,
#    'vulnerabilitynthe': 0,
#    'adclick': 0,
#    'insiders': 0,
#    'exercise': 0,
#    'surname': 0,
#    'obligations': 0,
#    'newcastle': 0,
#    'cease': 0,
#    'offers': 0,
#    'attacksnif': 0,
#    'restrictions': 0,
#    'rising': 0,
#    'olympic': 0,
#    'wpa': 0,
#    'completely': 0,
#    'informatica': 0,
#    'innby': 0,
#    'emailing': 0,
#    'theyd': 0,
#    'urging': 0,
#    'infectionnvulnerabilitiesnthis': 0,
#    'collapse': 0,
#    'malaysia': 0,
#    'studentsnmedia': 0,
#    'physical': 0,
#    'cryptocurrencynthe': 0,
#    'acknowledge': 0,
#    'passwordsnvulnerabilitiesnthere': 0,
#    'chats': 0,
#    'business': 0,
#    'phased': 0,
#    'onlinenyou': 0,
#    'hope': 0,
#    'hijacks': 0,
#    'daynused': 0,
#    'moneymotivated': 0,
#    'great': 0,
#    'attacknyou': 0,
#    'androidncisco': 0,
#    'quieter': 0,
#    'gadgets': 0,
#    'caribbean': 0,
#    'mostly': 0,
#    'buffer': 0,
#    'push': 0,
#    'finland': 0,
#    'sshaikhcoventryacuk': 0,
#    'festive': 0,
#    'periodicallynthis': 0,
#    'chris': 0,
#    'servicesnon': 0,
#    'seekna': 0,
#    'imgur': 0,
#    'attacknwe': 0,
#    'opening': 0,
#    'blognswedish': 0,
#    'undercutting': 0,
#    'conscious': 0,
#    'beta': 0,
#    'nandroid': 0,
#    'feasible': 0,
#    'iranian': 0,
#    'browse': 0,
#    'vulnerabilitynsecurity': 0,
#    'cashing': 0,
#    'crafting': 0,
#    'mere': 0,
#    'promote': 0,
#    'labsnit': 0,
#    'giftsnadvice': 0,
#    'gathered': 0,
#    'surveillance': 0,
#    'pwned': 0,
#    'design': 0,
#    'examplesnthe': 0,
#    'paymentnphishing': 0,
#    'zealand': 0,
#    'measurement': 0,
#    'lowest': 0,
#    'ian': 0,
#    'sectors': 0,
#    'clear': 0,
#    'started': 0,
#    'devicenkeep': 0,
#    'established': 0,
#    'proofpoints': 0,
#    'impossible': 0,
#    'measuring': 0,
#    'lie': 0,
#    'cvensap': 0,
#    'networksnukrainian': 0,
#    'fraudsters': 0,
#    'ncustomers': 0,
#    'productsnthe': 0,
#    'slowdown': 0,
#    'universal': 0,
#    'shipping': 0,
#    'misconfiguration': 0,
#    'specialists': 0,
#    'purposesnmalware': 0,
#    'logger': 0,
#    'possibility': 0,
#    'resource': 0,
#    'transportstyrelsen': 0,
#    'pertain': 0,
#    'outsourced': 0,
#    'allnmeanwhile': 0,
#    'hitting': 0,
#    'nresearchers': 0,
#    'webnan': 0,
#    'adapted': 0,
#    'backdoors': 0,
#    'index': 0,
#    'expertsna': 0,
#    'adjust': 0,
#    'youtube': 0,
#    'f': 0,
#    'previously': 0,
#    'recordings': 0,
#    'forhire': 0,
#    'parliament': 0,
#    'performing': 0,
#    'activated': 0,
#    'trustbased': 0,
#    'infect': 0,
#    'enabler': 0,
#    'schneider': 0,
#    'cent': 0,
#    'pull': 0,
#    'skimmer': 0,
#    'govuk': 0,
#    'concernednthis': 0,
#    'futurenweve': 0,
#    'downloadable': 0,
#    'quora': 0,
#    'presidential': 0,
#    'guidancenelection': 0,
#    'sporadically': 0,
#    'nonstate': 0,
#    'warnings': 0,
#    'apart': 0,
#    'qualifications': 0,
#    'produce': 0,
#    'reportedly': 0,
#    'residents': 0,
#    'industrynthis': 0,
#    'bn': 0,
#    'landscape': 0,
#    'heavily': 0,
#    'vbucks': 0,
#    'improve': 0,
#    'againnit': 0,
#    'yet': 0,
#    'responses': 0,
#    'results': 0,
#    'pain': 0,
#    'authenticity': 0,
#    'unaware': 0,
#    'themnmixing': 0,
#    'weve': 0,
#    'announced': 0,
#    'know': 0,
#    'websitenvulnerabilitiesnthere': 0,
#    'continued': 0,
#    'analyse': 0,
#    'websitenvmware': 0,
#    'christmas': 0,
#    'wiskunde': 0,
#    'findnin': 0,
#    'sets': 0,
#    'intermittent': 0,
#    'sourcendata': 0,
#    'softwaredefined': 0,
#    'apple': 0,
#    'sometimes': 0,
#    'bargain': 0,
#    'collective': 0,
#    'prosecution': 0,
#    'nxos': 0,
#    'serves': 0,
#    'collectionnaccording': 0,
#    'intrusion': 0,
#    'reproducing': 0,
#    'swift': 0,
#    'excess': 0,
#    'securities': 0,
#    'wwwactionfraudpoliceuk': 0,
#    'august': 0,
#    'eg': 0,
#    'clicked': 0,
#    'publishing': 0,
#    'knf': 0,
#    'extent': 0,
#    'protections': 0,
#    'household': 0,
#    'prevents': 0,
#    'posit': 0,
#    'virtualboxnelsewhere': 0,
#    'leitschuh': 0,
#    'responded': 0,
#    'removednnumber': 0,
#    'cryptographic': 0,
#    'traps': 0,
#    'accompanied': 0,
#    'thisnwith': 0,
#    'non': 0,
#    'letter': 0,
#    'unpaired': 0,
#    'disappointed': 0,
#    'passwordstuffing': 0,
#    'neutralises': 0,
#    'suited': 0,
#    'eventual': 0,
#    'flashpoint': 0,
#    'strengthens': 0,
#    'cardnonline': 0,
#    'terms': 0,
#    'directly': 0,
#    'dharma': 0,
#    'itngranting': 0,
#    'enabled': 0,
#    'scammer': 0,
#    'luck': 0,
#    'serious': 0,
#    'googles': 0,
#    'vector': 0,
#    'popularnaccording': 0,
#    'spent': 0,
#    'tackling': 0,
#    'choices': 0,
#    'internetna': 0,
#    'gwrcom': 0,
#    'patchnas': 0,
#    'incidentsnweve': 0,
#    'metronbad': 0,
#    'doj': 0,
#    'gigabits': 0,
#    'devicesncomrat': 0,
#    'repetitive': 0,
#    'roughted': 0,
#    'duplicatesnsms': 0,
#    'detectionnsowburgs': 0,
#    'unspecified': 0,
#    'companies': 0,
#    'ring': 0,
#    'resilience': 0,
#    'analytics': 0,
#    'flawsnthe': 0,
#    'life': 0,
#    'newbie': 0,
#    'bulk': 0,
#    'numbersntiktoks': 0,
#    'terrorist': 0,
#    'providersna': 0,
#    'validation': 0,
#    'bar': 0,
#    'paralympic': 0,
#    'nessus': 0,
#    'march': 0,
#    'background': 0,
#    'germanys': 0,
#    'makers': 0,
#    'highprofile': 0,
#    'compromisenidentifying': 0,
#    'services': 0,
#    'searches': 0,
#    'innocuous': 0,
#    'pnrnresearchers': 0,
#    'obtainedndisgruntled': 0,
#    'eventually': 0,
#    'hall': 0,
#    'bills': 0,
#    'manufacture': 0,
#    'signing': 0,
#    'cyberexposure': 0,
#    'leasing': 0,
#    'thinks': 0,
#    'mmo': 0,
#    'existed': 0,
#    'intended': 0,
#    'zeroday': 0,
#    'backups': 0,
#    'servicesnsome': 0,
#    'versionsnmicrosoft': 0,
#    'bodybuildingcom': 0,
#    'dupe': 0,
#    'internetnrecent': 0,
#    'deployed': 0,
#    'flexibility': 0,
#    'submitted': 0,
#    'redcar': 0,
#    'patchednorganisations': 0,
#    'election': 0,
#    'view': 0,
#    'asia': 0,
#    'aggressively': 0,
#    'portions': 0,
#    'licence': 0,
#    'administer': 0,
#    'disgruntled': 0,
#    'standards': 0,
#    'context': 0,
#    'messagesntrue': 0,
#    'filters': 0,
#    'journalists': 0,
#    'sri': 0,
#    'securing': 0,
#    'usernames': 0,
#    'accountsnafter': 0,
#    'gave': 0,
#    'varies': 0,
#    'toysnthe': 0,
#    'stickers': 0,
#    'cvv': 0,
#    'scheduled': 0,
#    'pocketnaccording': 0,
#    'driver': 0,
#    'reloadnin': 0,
#    'mobilebased': 0,
#    'super': 0,
#    'accountability': 0,
#    'paul': 0,
#    'fraudnthe': 0,
#    'saved': 0,
#    'ensure': 0,
#    'little': 0,
#    'payloadnavasts': 0,
#    'majesty': 0,
#    'reused': 0,
#    'guilty': 0,
#    'agent': 0,
#    'refers': 0,
#    'fbiufissued': 0,
#    'februarynsha': 0,
#    'jailedna': 0,
#    'relies': 0,
#    'cleaner': 0,
#    'channel': 0,
#    'power': 0,
#    'times': 0,
#    'full': 0,
#    'rnall': 0,
#    'herena': 0,
#    'ubers': 0,
#    'centres': 0,
#    'responding': 0,
#    'ownership': 0,
#    'easier': 0,
#    'compliance': 0,
#    'exposedntwitter': 0,
#    'challengesnpasswords': 0,
#    'trash': 0,
#    'upcoming': 0,
#    'probably': 0,
#    'smallest': 0,
#    'soufthe': 0,
#    'heighten': 0,
#    'removes': 0,
#    'conclusion': 0,
#    'imposed': 0,
#    'victimsnthe': 0,
#    'rich': 0,
#    'since': 0,
#    'conclusively': 0,
#    'isps': 0,
#    'necessarily': 0,
#    'youre': 0,
#    'paywallnchris': 0,
#    'reset': 0,
#    'four': 0,
#    'default': 0,
#    'backup': 0,
#    'easiest': 0,
#    'coursework': 0,
#    'dramatically': 0,
#    'compromised': 0,
#    'cveninformation': 0,
#    'accessnhackers': 0,
#    'additionally': 0,
#    'bitcoinnin': 0,
#    'vital': 0,
#    'providersnthe': 0,
#    'friend': 0,
#    'harvest': 0,
#    'yearnmicrosoft': 0,
#    'qualification': 0,
#    'administratorsnresearch': 0,
#    'measured': 0,
#    'japans': 0,
#    'agreed': 0,
#    'ashley': 0,
#    'redundancy': 0,
#    'cve': 0,
#    'hardtoguess': 0,
#    'jackpotting': 0,
#    'knuddels': 0,
#    'httpswwwcpnigovukinsiderthreat': 0,
#    'ursnifs': 0,
#    'theories': 0,
#    'injected': 0,
#    'equipment': 0,
#    'switching': 0,
#    'prolific': 0,
#    'debating': 0,
#    'http': 0,
#    'qwerty': 0,
#    'enforced': 0,
#    'imitate': 0,
#    'factor': 0,
#    'preventionnjust': 0,
#    'thisnlike': 0,
#    'remediation': 0,
#    ...}),
#  ('16th April 2021',
#   {'connected': 1,
#    'ncsc': 6,
#    'eligibility': 1,
#    'recommends': 2,
#    'us': 1,
#    'compromisenthe': 1,
#    'highly': 1,
#    'unauthorised': 1,
#    'management': 1,
#    'microsoft': 5,
#    'critical': 1,
#    'partnered': 1,
#    'server': 6,
#    'could': 2,
#    'subsequent': 1,
#    'risknin': 1,
#    'organisations': 4,
#    'code': 1,
#    'month': 2,
#    'access': 1,
#    'new': 2,
#    'based': 1,
#    'popular': 1,
#    'mitigations': 1,
#    'guidance': 2,
#    'assesses': 1,
#    'research': 1,
#    'suggest': 1,
#    'news': 1,
#    'security': 4,
#    'statement': 1,
#    'action': 1,
#    'dns': 2,
#    'soon': 1,
#    'four': 1,
#    'impact': 1,
#    'mitigation': 1,
#    'foreign': 2,
#    'practicablenas': 1,
#    'suspicious': 1,
#    'uk': 2,
#    'exploited': 1,
#    'read': 1,
#    'secretarys': 1,
#    'reporting': 1,
#    'attackersnthe': 1,
#    'forescout': 2,
#    'administrators': 1,
#    'domain': 1,
#    'patches': 1,
#    'targetingnthe': 1,
#    'software': 2,
#    'arenexchange': 1,
#    'team': 1,
#    'denial': 1,
#    'versions': 2,
#    'immediately': 1,
#    'actively': 1,
#    'updates': 3,
#    'targeted': 1,
#    'names': 1,
#    'cycle': 1,
#    'enable': 1,
#    'issued': 1,
#    'practice': 1,
#    'herenthe': 1,
#    'execution': 1,
#    'criteria': 1,
#    'installing': 1,
#    'companys': 1,
#    'manufacturing': 1,
#    'exploitation': 1,
#    'svr': 2,
#    'following': 2,
#    'usagenyou': 1,
#    'follows': 1,
#    'full': 1,
#    'public': 2,
#    'latest': 1,
#    'retail': 1,
#    'private': 1,
#    'intrusions': 1,
#    'ipnet': 1,
#    'centre': 1,
#    'series': 3,
#    'vulnerabilitiesnmore': 1,
#    'stacks': 1,
#    'national': 1,
#    'disclosed': 1,
#    'gchq': 1,
#    'devices': 2,
#    'pdns': 1,
#    'worldwidencalifornia': 1,
#    'net': 1,
#    'internet': 1,
#    'servers': 2,
#    'million': 1,
#    'cyber': 3,
#    'namewreck': 1,
#    'week': 1,
#    'nine': 1,
#    'sizesninformation': 1,
#    'freebsd': 1,
#    'exchange': 6,
#    'govuk': 1,
#    'advice': 1,
#    'intelligence': 1,
#    'ncscs': 1,
#    'known': 1,
#    'revealed': 1,
#    'jsof': 2,
#    'around': 1,
#    'uncovered': 1,
#    'healthcare': 1,
#    'part': 2,
#    'tcpip': 1,
#    'protective': 1,
#    'update': 1,
#    'blog': 1,
#    'nucleus': 1,
#    'estimated': 1,
#    'netxnthese': 1,
#    'compromisendealing': 1,
#    'orion': 2,
#    'released': 2,
#    'service': 2,
#    'including': 3,
#    'found': 3,
#    'nexchange': 3,
#    'install': 2,
#    'time': 1,
#    'step': 1,
#    'russias': 1,
#    'published': 2,
#    'servernwhile': 1,
#    'best': 1,
#    'credential': 1,
#    'gaining': 1,
#    'previously': 1,
#    'company': 1,
#    'alone': 1,
#    'solarwinds': 3,
#    'government': 1,
#    'either': 1,
#    'affecting': 1,
#    'written': 1,
#    'sector': 1,
#    'information': 2,
#    'sectors': 1,
#    'severity': 1,
#    'remote': 1,
#    'alert': 2,
#    'first': 2,
#    'vulnerabilities': 7,
#    'scheduled': 1,
#    'researchers': 1,
#    'encouraging': 1,
#    'last': 2,
#    'responsible': 1,
#    'behind': 1,
#    'affected': 2,
#    'vendor': 1,
#    'address': 1,
#    'likely': 1,
#    'compromisenidentifying': 1,
#    'collectively': 1,
#    'recommended': 1,
#    'urge': 0,
#    'herenformer': 0,
#    'industriesnthe': 0,
#    'settings': 0,
#    'forensic': 0,
#    'policymaking': 0,
#    'incidents': 0,
#    'reviews': 0,
#    'securenfrom': 0,
#    'issues': 0,
#    'fbis': 0,
#    'usefulndefending': 0,
#    'hat': 0,
#    'servicenthe': 0,
#    'agreement': 0,
#    'chip': 0,
#    'bruteforce': 0,
#    'strobe': 0,
#    'limitations': 0,
#    'msn': 0,
#    'storage': 0,
#    'illegitimately': 0,
#    'magecarts': 0,
#    'capitalise': 0,
#    'obsolete': 0,
#    'filed': 0,
#    'sweden': 0,
#    'right': 0,
#    'hns': 0,
#    'increasensocial': 0,
#    'notifications': 0,
#    'permissions': 0,
#    'distributes': 0,
#    'nany': 0,
#    'conductednindia': 0,
#    'workaround': 0,
#    'worrying': 0,
#    'depend': 0,
#    'discountnearlier': 0,
#    'asavie': 0,
#    'devicesnhns': 0,
#    'concernsnretailer': 0,
#    'whereby': 0,
#    'taking': 0,
#    'passed': 0,
#    'fin': 0,
#    'lucrative': 0,
#    'binary': 0,
#    'periphery': 0,
#    'apologised': 0,
#    'fixednthe': 0,
#    'updatesnthe': 0,
#    'celebrity': 0,
#    'undermines': 0,
#    'active': 0,
#    'devicesnthe': 0,
#    'memory': 0,
#    'strategically': 0,
#    'kitnhowever': 0,
#    'decryption': 0,
#    'suffered': 0,
#    'outcomesnfor': 0,
#    'unannounced': 0,
#    'banks': 0,
#    'servicesnsources': 0,
#    'forthcoming': 0,
#    'dont': 0,
#    'april': 0,
#    'managernduring': 0,
#    'disguising': 0,
#    'implementing': 0,
#    'u': 0,
#    'quietly': 0,
#    'overnight': 0,
#    'devicenthis': 0,
#    'entry': 0,
#    'attachment': 0,
#    'study': 0,
#    'utterly': 0,
#    'escape': 0,
#    'hackingnvulnerability': 0,
#    'versionna': 0,
#    'stuntman': 0,
#    'accountsnnnintendo': 0,
#    'improved': 0,
#    'brandnew': 0,
#    'craft': 0,
#    'infrastructure': 0,
#    'harnessing': 0,
#    'athletes': 0,
#    'carry': 0,
#    'open': 0,
#    'agencies': 0,
#    'bugsnsymantec': 0,
#    'aid': 0,
#    'beufreported': 0,
#    'viewing': 0,
#    'mysql': 0,
#    'pewdiepie': 0,
#    'earliernthe': 0,
#    'impersonate': 0,
#    'interfax': 0,
#    'status': 0,
#    'updated': 0,
#    'servicenthere': 0,
#    'respectively': 0,
#    'breachn': 0,
#    'publishes': 0,
#    'neglect': 0,
#    'finansowego': 0,
#    'komisja': 0,
#    'blockchain': 0,
#    'loss': 0,
#    'checkout': 0,
#    'prosecutors': 0,
#    'npassword': 0,
#    'notable': 0,
#    'generate': 0,
#    'lose': 0,
#    'fixesnany': 0,
#    'categorises': 0,
#    'detectionevasion': 0,
#    'ncscncryptomining': 0,
#    'controversynswedens': 0,
#    'exfiltration': 0,
#    'pleads': 0,
#    'circulating': 0,
#    'standardcompliant': 0,
#    'coldfusion': 0,
#    'beijingnmicrosoft': 0,
#    'launch': 0,
#    'indexed': 0,
#    'estimate': 0,
#    'perl': 0,
#    'neo': 0,
#    'gwr': 0,
#    'netlogon': 0,
#    'chancellor': 0,
#    'verification': 0,
#    'ecsepa': 0,
#    'ostensibly': 0,
#    'optimised': 0,
#    'rtf': 0,
#    'stressed': 0,
#    'numbersnthe': 0,
#    'safenchallenge': 0,
#    'affiliating': 0,
#    'delays': 0,
#    'italy': 0,
#    'possiblennthe': 0,
#    'recklessly': 0,
#    'subscription': 0,
#    'linkedin': 0,
#    'figuresnthe': 0,
#    'angus': 0,
#    'fixingnwhile': 0,
#    'apples': 0,
#    'nnthe': 0,
#    'outcome': 0,
#    'rescue': 0,
#    'roughly': 0,
#    'requestnimpersonation': 0,
#    'linknryuk': 0,
#    'port': 0,
#    'watchdog': 0,
#    'california': 0,
#    'sophistication': 0,
#    'poland': 0,
#    'large': 0,
#    'graphic': 0,
#    'jailed': 0,
#    'tested': 0,
#    'exfiltrated': 0,
#    'setup': 0,
#    'area': 0,
#    'respondents': 0,
#    'worryingly': 0,
#    'internetenabled': 0,
#    'gates': 0,
#    'frozen': 0,
#    'consequence': 0,
#    'websites': 0,
#    'sentry': 0,
#    'cycon': 0,
#    'nthese': 0,
#    'ot': 0,
#    'photocopiers': 0,
#    'type': 0,
#    'leverages': 0,
#    'operationsnthe': 0,
#    'nwhile': 0,
#    'helpfully': 0,
#    'outsourcing': 0,
#    'tool': 0,
#    'space': 0,
#    'combinedninsurers': 0,
#    'prioritynthe': 0,
#    'wed': 0,
#    'generation': 0,
#    'sort': 0,
#    'yearna': 0,
#    'theyre': 0,
#    'capability': 0,
#    'prompt': 0,
#    'nthis': 0,
#    'civil': 0,
#    'world': 0,
#    'purposesnthe': 0,
#    'contracts': 0,
#    'emergence': 0,
#    'centrenfebruary': 0,
#    'pandemicnhowever': 0,
#    'boarding': 0,
#    'postnthe': 0,
#    'file': 0,
#    'cyberuk': 0,
#    'activitynmalware': 0,
#    'deliberate': 0,
#    'result': 0,
#    'spam': 0,
#    'reminder': 0,
#    'indeed': 0,
#    'martin': 0,
#    'empowering': 0,
#    'overlord': 0,
#    'containing': 0,
#    'stored': 0,
#    'graham': 0,
#    'responsenragnar': 0,
#    'lowquality': 0,
#    'controllers': 0,
#    'sheraton': 0,
#    'figures': 0,
#    'reparationnorganisations': 0,
#    'authored': 0,
#    'compromisena': 0,
#    'grow': 0,
#    'jpeg': 0,
#    'thing': 0,
#    'onlinenadvice': 0,
#    'pdf': 0,
#    'traditional': 0,
#    'vulnerability': 0,
#    'minimum': 0,
#    'discovery': 0,
#    'start': 0,
#    'collect': 0,
#    'disruptionnthe': 0,
#    'domains': 0,
#    'singlesign': 0,
#    'personal': 0,
#    'conducing': 0,
#    'scheme': 0,
#    'confiscated': 0,
#    'newernthe': 0,
#    'unavailable': 0,
#    'mexicos': 0,
#    'ndigital': 0,
#    'socially': 0,
#    'icedovethunderbird': 0,
#    'cited': 0,
#    'highlights': 0,
#    'informationnan': 0,
#    'bundled': 0,
#    'taiwanbased': 0,
#    'malware': 0,
#    'anticipate': 0,
#    'attackednon': 0,
#    'sporting': 0,
#    'content': 0,
#    'holidays': 0,
#    'happening': 0,
#    'tvnus': 0,
#    'qbot': 0,
#    'sums': 0,
#    'agencyufencourages': 0,
#    'sticks': 0,
#    'exciting': 0,
#    'deleting': 0,
#    'interests': 0,
#    'prepare': 0,
#    'overview': 0,
#    'securitynequifax': 0,
#    'enterprise': 0,
#    'accountinternetcomputer': 0,
#    'travelling': 0,
#    'expired': 0,
#    'profited': 0,
#    'ceases': 0,
#    'intact': 0,
#    'purported': 0,
#    'enumeration': 0,
#    'federation': 0,
#    'subscribers': 0,
#    'bring': 0,
#    'opportunity': 0,
#    'accountsnadvice': 0,
#    'credit': 0,
#    'diseases': 0,
#    'unauthorized': 0,
#    'leaves': 0,
#    'failings': 0,
#    'equivalent': 0,
#    'screens': 0,
#    'inevitable': 0,
#    'deliveries': 0,
#    'sends': 0,
#    'attacksnover': 0,
#    'controllersnthere': 0,
#    'six': 0,
#    'crimesnthis': 0,
#    'harvesting': 0,
#    'pixelsnthere': 0,
#    'earliest': 0,
#    'threatsnthe': 0,
#    'trickbot': 0,
#    'confirm': 0,
#    'consumers': 0,
#    'stuffing': 0,
#    'ncriminals': 0,
#    'addressed': 0,
#    'analysis': 0,
#    'extreme': 0,
#    'emailsnaction': 0,
#    'discreet': 0,
#    'build': 0,
#    'spoofed': 0,
#    'vietnam': 0,
#    'panic': 0,
#    'phishingnnnew': 0,
#    'onlinenthe': 0,
#    'r': 0,
#    'wellmess': 0,
#    'frauds': 0,
#    'safeguardsnts': 0,
#    'highlight': 0,
#    'corruption': 0,
#    'running': 0,
#    'claimed': 0,
#    'reminds': 0,
#    'sitenmicrosoft': 0,
#    'regarding': 0,
#    'compromising': 0,
#    'impactncryptocurrencies': 0,
#    'reading': 0,
#    'zendesk': 0,
#    'immediatelynmore': 0,
#    'apply': 0,
#    'qemu': 0,
#    'estatenfurther': 0,
#    'localisation': 0,
#    'onto': 0,
#    'neven': 0,
#    'releasednwe': 0,
#    'executionnibm': 0,
#    'student': 0,
#    'year': 0,
#    'ombudsman': 0,
#    'thanks': 0,
#    'groups': 0,
#    'sensitive': 0,
#    'clinic': 0,
#    'fundamental': 0,
#    'credentialsnelsewhere': 0,
#    'buckets': 0,
#    'even': 0,
#    'evaluating': 0,
#    'swipe': 0,
#    'addressninterestingly': 0,
#    'introduction': 0,
#    'founded': 0,
#    'educations': 0,
#    'sectorsnthe': 0,
#    'ndnthe': 0,
#    'rises': 0,
#    'investigated': 0,
#    'nour': 0,
#    'squad': 0,
#    'record': 0,
#    'callsnthe': 0,
#    'well': 0,
#    'yearround': 0,
#    'theftnuscert': 0,
#    'aims': 0,
#    'creates': 0,
#    'standard': 0,
#    'chineseaffiliated': 0,
#    'scamsnnphishing': 0,
#    'identifiedndue': 0,
#    'commitment': 0,
#    'attempting': 0,
#    'everyday': 0,
#    'meltdown': 0,
#    'checked': 0,
#    'style': 0,
#    'customersnantitheft': 0,
#    'requests': 0,
#    'brand': 0,
#    'thisnwhile': 0,
#    'usdnfeibs': 0,
#    'remained': 0,
#    'store': 0,
#    'unfixed': 0,
#    'underwent': 0,
#    'judgement': 0,
#    'remerged': 0,
#    'scale': 0,
#    'movementsnfrom': 0,
#    'rnwindows': 0,
#    'acknowledging': 0,
#    'selectednyou': 0,
#    'change': 0,
#    'enhance': 0,
#    'zdnet': 0,
#    'guidensmall': 0,
#    'mail': 0,
#    'review': 0,
#    'attacknthe': 0,
#    'establishment': 0,
#    'pwc': 0,
#    'understood': 0,
#    'litigation': 0,
#    'engagement': 0,
#    'earned': 0,
#    'rafotecs': 0,
#    'seeking': 0,
#    'pandemicnnthe': 0,
#    'coronavirusrelated': 0,
#    'cybereason': 0,
#    'investors': 0,
#    'toyotas': 0,
#    'roughtedrelated': 0,
#    'managed': 0,
#    'commissioner': 0,
#    'blaming': 0,
#    'terabits': 0,
#    'smb': 0,
#    'vulnerabilitynthe': 0,
#    'adclick': 0,
#    'insiders': 0,
#    'exercise': 0,
#    'surname': 0,
#    'obligations': 0,
#    'newcastle': 0,
#    'cease': 0,
#    'offers': 0,
#    'attacksnif': 0,
#    'restrictions': 0,
#    'rising': 0,
#    'olympic': 0,
#    'wpa': 0,
#    'completely': 0,
#    'informatica': 0,
#    'innby': 0,
#    'emailing': 0,
#    'theyd': 0,
#    'urging': 0,
#    'infectionnvulnerabilitiesnthis': 0,
#    'collapse': 0,
#    'malaysia': 0,
#    'studentsnmedia': 0,
#    'physical': 0,
#    'cryptocurrencynthe': 0,
#    'acknowledge': 0,
#    'passwordsnvulnerabilitiesnthere': 0,
#    'chats': 0,
#    'business': 0,
#    'phased': 0,
#    'onlinenyou': 0,
#    'hope': 0,
#    'hijacks': 0,
#    'daynused': 0,
#    'moneymotivated': 0,
#    'great': 0,
#    'attacknyou': 0,
#    'androidncisco': 0,
#    'quieter': 0,
#    'gadgets': 0,
#    'caribbean': 0,
#    'mostly': 0,
#    'buffer': 0,
#    'push': 0,
#    'finland': 0,
#    'sshaikhcoventryacuk': 0,
#    'festive': 0,
#    'periodicallynthis': 0,
#    'chris': 0,
#    'servicesnon': 0,
#    'seekna': 0,
#    'imgur': 0,
#    'attacknwe': 0,
#    'opening': 0,
#    'blognswedish': 0,
#    'undercutting': 0,
#    'conscious': 0,
#    'beta': 0,
#    'nandroid': 0,
#    'feasible': 0,
#    'iranian': 0,
#    'browse': 0,
#    'vulnerabilitynsecurity': 0,
#    'cashing': 0,
#    'crafting': 0,
#    'mere': 0,
#    'promote': 0,
#    'labsnit': 0,
#    'giftsnadvice': 0,
#    'gathered': 0,
#    'surveillance': 0,
#    'pwned': 0,
#    'design': 0,
#    'examplesnthe': 0,
#    'paymentnphishing': 0,
#    'zealand': 0,
#    'measurement': 0,
#    'lowest': 0,
#    'ian': 0,
#    'clear': 0,
#    'started': 0,
#    'devicenkeep': 0,
#    'established': 0,
#    'proofpoints': 0,
#    'impossible': 0,
#    'measuring': 0,
#    'lie': 0,
#    'cvensap': 0,
#    'networksnukrainian': 0,
#    'fraudsters': 0,
#    'ncustomers': 0,
#    'productsnthe': 0,
#    'slowdown': 0,
#    'universal': 0,
#    'shipping': 0,
#    'misconfiguration': 0,
#    'specialists': 0,
#    'purposesnmalware': 0,
#    'logger': 0,
#    'possibility': 0,
#    'resource': 0,
#    'transportstyrelsen': 0,
#    'pertain': 0,
#    'outsourced': 0,
#    'allnmeanwhile': 0,
#    'hitting': 0,
#    'nresearchers': 0,
#    'webnan': 0,
#    'adapted': 0,
#    'backdoors': 0,
#    'index': 0,
#    'expertsna': 0,
#    'adjust': 0,
#    'youtube': 0,
#    'f': 0,
#    'recordings': 0,
#    'forhire': 0,
#    'parliament': 0,
#    'performing': 0,
#    'activated': 0,
#    'trustbased': 0,
#    'infect': 0,
#    'enabler': 0,
#    'schneider': 0,
#    'cent': 0,
#    'pull': 0,
#    'skimmer': 0,
#    'concernednthis': 0,
#    'futurenweve': 0,
#    'downloadable': 0,
#    'quora': 0,
#    'presidential': 0,
#    'guidancenelection': 0,
#    'sporadically': 0,
#    'nonstate': 0,
#    'warnings': 0,
#    'apart': 0,
#    'qualifications': 0,
#    'produce': 0,
#    'reportedly': 0,
#    'residents': 0,
#    'industrynthis': 0,
#    'bn': 0,
#    'landscape': 0,
#    'heavily': 0,
#    'vbucks': 0,
#    'improve': 0,
#    'againnit': 0,
#    'yet': 0,
#    'responses': 0,
#    'results': 0,
#    'pain': 0,
#    'authenticity': 0,
#    'unaware': 0,
#    'themnmixing': 0,
#    'weve': 0,
#    'announced': 0,
#    'know': 0,
#    'websitenvulnerabilitiesnthere': 0,
#    'continued': 0,
#    'analyse': 0,
#    'websitenvmware': 0,
#    'christmas': 0,
#    'wiskunde': 0,
#    'findnin': 0,
#    'sets': 0,
#    'intermittent': 0,
#    'sourcendata': 0,
#    'softwaredefined': 0,
#    'behaviour': 0,
#    'apple': 0,
#    'sometimes': 0,
#    'bargain': 0,
#    'collective': 0,
#    'prosecution': 0,
#    'nxos': 0,
#    'serves': 0,
#    'collectionnaccording': 0,
#    'intrusion': 0,
#    'reproducing': 0,
#    'swift': 0,
#    'excess': 0,
#    'securities': 0,
#    'wwwactionfraudpoliceuk': 0,
#    'august': 0,
#    'eg': 0,
#    'clicked': 0,
#    'publishing': 0,
#    'knf': 0,
#    'extent': 0,
#    'protections': 0,
#    'household': 0,
#    'prevents': 0,
#    'posit': 0,
#    'virtualboxnelsewhere': 0,
#    'leitschuh': 0,
#    'responded': 0,
#    'removednnumber': 0,
#    'cryptographic': 0,
#    'traps': 0,
#    'accompanied': 0,
#    'thisnwith': 0,
#    'non': 0,
#    'letter': 0,
#    'unpaired': 0,
#    'disappointed': 0,
#    'passwordstuffing': 0,
#    'neutralises': 0,
#    'suited': 0,
#    'eventual': 0,
#    'flashpoint': 0,
#    'strengthens': 0,
#    'cardnonline': 0,
#    'terms': 0,
#    'directly': 0,
#    'dharma': 0,
#    'itngranting': 0,
#    'enabled': 0,
#    'scammer': 0,
#    'luck': 0,
#    'serious': 0,
#    'googles': 0,
#    'vector': 0,
#    'popularnaccording': 0,
#    'spent': 0,
#    'tackling': 0,
#    'choices': 0,
#    'internetna': 0,
#    'gwrcom': 0,
#    'patchnas': 0,
#    'incidentsnweve': 0,
#    'metronbad': 0,
#    'doj': 0,
#    'gigabits': 0,
#    'devicesncomrat': 0,
#    'repetitive': 0,
#    'roughted': 0,
#    'duplicatesnsms': 0,
#    'detectionnsowburgs': 0,
#    'unspecified': 0,
#    'companies': 0,
#    'ring': 0,
#    'resilience': 0,
#    'analytics': 0,
#    'flawsnthe': 0,
#    'life': 0,
#    'newbie': 0,
#    'bulk': 0,
#    'numbersntiktoks': 0,
#    'terrorist': 0,
#    'providersna': 0,
#    'validation': 0,
#    'bar': 0,
#    'paralympic': 0,
#    'nessus': 0,
#    'march': 0,
#    'background': 0,
#    'germanys': 0,
#    'makers': 0,
#    'highprofile': 0,
#    'services': 0,
#    'searches': 0,
#    'innocuous': 0,
#    'pnrnresearchers': 0,
#    'obtainedndisgruntled': 0,
#    'eventually': 0,
#    'hall': 0,
#    'bills': 0,
#    'manufacture': 0,
#    'signing': 0,
#    'cyberexposure': 0,
#    'leasing': 0,
#    'thinks': 0,
#    'mmo': 0,
#    'existed': 0,
#    'intended': 0,
#    'zeroday': 0,
#    'backups': 0,
#    'servicesnsome': 0,
#    'versionsnmicrosoft': 0,
#    'bodybuildingcom': 0,
#    'dupe': 0,
#    'internetnrecent': 0,
#    'deployed': 0,
#    'flexibility': 0,
#    'submitted': 0,
#    'redcar': 0,
#    'patchednorganisations': 0,
#    'election': 0,
#    'view': 0,
#    'asia': 0,
#    'aggressively': 0,
#    'portions': 0,
#    'licence': 0,
#    'administer': 0,
#    'disgruntled': 0,
#    'standards': 0,
#    'context': 0,
#    'messagesntrue': 0,
#    'filters': 0,
#    'journalists': 0,
#    'sri': 0,
#    'securing': 0,
#    'usernames': 0,
#    'accountsnafter': 0,
#    'gave': 0,
#    'varies': 0,
#    'toysnthe': 0,
#    'stickers': 0,
#    'cvv': 0,
#    'pocketnaccording': 0,
#    'driver': 0,
#    'reloadnin': 0,
#    'mobilebased': 0,
#    'super': 0,
#    'accountability': 0,
#    'paul': 0,
#    'fraudnthe': 0,
#    'saved': 0,
#    'ensure': 0,
#    'little': 0,
#    'payloadnavasts': 0,
#    'majesty': 0,
#    'reused': 0,
#    'guilty': 0,
#    'agent': 0,
#    'refers': 0,
#    'fbiufissued': 0,
#    'februarynsha': 0,
#    'jailedna': 0,
#    'relies': 0,
#    'cleaner': 0,
#    'channel': 0,
#    'power': 0,
#    'times': 0,
#    'rnall': 0,
#    'herena': 0,
#    'ubers': 0,
#    'centres': 0,
#    'responding': 0,
#    'ownership': 0,
#    'easier': 0,
#    'compliance': 0,
#    'exposedntwitter': 0,
#    'challengesnpasswords': 0,
#    'trash': 0,
#    'upcoming': 0,
#    'probably': 0,
#    'smallest': 0,
#    'soufthe': 0,
#    'heighten': 0,
#    'removes': 0,
#    'conclusion': 0,
#    'imposed': 0,
#    'victimsnthe': 0,
#    'rich': 0,
#    'since': 0,
#    'conclusively': 0,
#    'isps': 0,
#    'necessarily': 0,
#    'youre': 0,
#    'paywallnchris': 0,
#    'reset': 0,
#    'default': 0,
#    'backup': 0,
#    'easiest': 0,
#    'coursework': 0,
#    'dramatically': 0,
#    'compromised': 0,
#    'cveninformation': 0,
#    'accessnhackers': 0,
#    'additionally': 0,
#    'bitcoinnin': 0,
#    'vital': 0,
#    'providersnthe': 0,
#    'friend': 0,
#    'harvest': 0,
#    'yearnmicrosoft': 0,
#    'qualification': 0,
#    'administratorsnresearch': 0,
#    'measured': 0,
#    'japans': 0,
#    'agreed': 0,
#    'ashley': 0,
#    'redundancy': 0,
#    'cve': 0,
#    'hardtoguess': 0,
#    'jackpotting': 0,
#    'knuddels': 0,
#    'httpswwwcpnigovukinsiderthreat': 0,
#    'ursnifs': 0,
#    'theories': 0,
#    'injected': 0,
#    'equipment': 0,
#    'switching': 0,
#    ...}),
#  ('12th April 2021',
#   {'ncsc': 3,
#    'online': 2,
#    'countries': 1,
#    'groups': 1,
#    'joint': 1,
#    'whether': 1,
#    'two': 1,
#    'critical': 1,
#    'apt': 1,
#    'continued': 1,
#    'organisations': 1,
#    'using': 3,
#    'access': 1,
#    'phone': 1,
#    'new': 3,
#    'vpn': 3,
#    'vulnerabilitynapt': 1,
#    'allow': 1,
#    'guidance': 1,
#    'report': 1,
#    'criminals': 1,
#    'security': 2,
#    'statement': 1,
#    'individuals': 1,
#    'action': 1,
#    'soon': 1,
#    'plugins': 1,
#    'response': 1,
#    'impact': 1,
#    'spearphishing': 1,
#    'evidence': 1,
#    'attack': 1,
#    'zip': 1,
#    'cve': 3,
#    'uknfacebook': 1,
#    'warned': 2,
#    'fbi': 1,
#    'lurenif': 1,
#    'software': 1,
#    'breach': 1,
#    'ensure': 1,
#    'numbers': 1,
#    'cisa': 1,
#    'job': 2,
#    'victim': 1,
#    'devicesnwe': 1,
#    'useful': 1,
#    'signs': 1,
#    'actively': 1,
#    'scam': 1,
#    'ids': 1,
#    'updates': 1,
#    'campaign': 1,
#    'moreeggs': 1,
#    'victims': 1,
#    'successful': 1,
#    'trigger': 1,
#    'download': 1,
#    'issued': 2,
#    'breached': 1,
#    'people': 1,
#    'provide': 1,
#    'harmful': 2,
#    'data': 2,
#    'email': 1,
#    'offer': 1,
#    'full': 1,
#    'latest': 1,
#    'breaches': 1,
#    'linkedin': 1,
#    'spot': 1,
#    'possible': 1,
#    'media': 1,
#    'social': 1,
#    'exploiting': 1,
#    'unpatched': 1,
#    'vulnerabilitiesnmore': 1,
#    'across': 1,
#    'find': 1,
#    'disclosed': 1,
#    'date': 1,
#    'devices': 1,
#    'reportnwe': 1,
#    'million': 3,
#    'profile': 1,
#    'malicious': 2,
#    'said': 1,
#    'cyber': 2,
#    'urge': 1,
#    'computernthe': 1,
#    'safely': 1,
#    'listed': 1,
#    'obvious': 1,
#    'advice': 1,
#    'covers': 1,
#    'ncscs': 1,
#    'known': 1,
#    'trojan': 1,
#    'actors': 1,
#    'fake': 1,
#    'ndespite': 1,
#    'fortinet': 4,
#    'position': 1,
#    'installed': 2,
#    'location': 1,
#    'gender': 1,
#    'warning': 1,
#    'scan': 1,
#    'persistent': 1,
#    'files': 1,
#    'including': 1,
#    'users': 2,
#    'found': 1,
#    'toolnthe': 1,
#    'phishing': 1,
#    'targets': 2,
#    'would': 2,
#    'published': 1,
#    'previously': 1,
#    'protect': 1,
#    'fraud': 1,
#    'opened': 1,
#    'information': 2,
#    'advanced': 1,
#    'backdoor': 1,
#    'posted': 1,
#    'alert': 1,
#    'esentire': 1,
#    'believe': 1,
#    'vulnerabilities': 2,
#    'researchers': 1,
#    'vulnerability': 1,
#    'birthnresearchers': 1,
#    'threat': 1,
#    'facebook': 2,
#    'pwned': 1,
#    'installation': 1,
#    'herenformer': 0,
#    'industriesnthe': 0,
#    'settings': 0,
#    'forensic': 0,
#    'policymaking': 0,
#    'incidents': 0,
#    'reviews': 0,
#    'securenfrom': 0,
#    'issues': 0,
#    'fbis': 0,
#    'usefulndefending': 0,
#    'hat': 0,
#    'servicenthe': 0,
#    'agreement': 0,
#    'chip': 0,
#    'bruteforce': 0,
#    'strobe': 0,
#    'limitations': 0,
#    'msn': 0,
#    'storage': 0,
#    'illegitimately': 0,
#    'magecarts': 0,
#    'capitalise': 0,
#    'obsolete': 0,
#    'filed': 0,
#    'sweden': 0,
#    'right': 0,
#    'hns': 0,
#    'increasensocial': 0,
#    'notifications': 0,
#    'permissions': 0,
#    'distributes': 0,
#    'nany': 0,
#    'conductednindia': 0,
#    'workaround': 0,
#    'worrying': 0,
#    'depend': 0,
#    'discountnearlier': 0,
#    'asavie': 0,
#    'devicesnhns': 0,
#    'concernsnretailer': 0,
#    'whereby': 0,
#    'taking': 0,
#    'passed': 0,
#    'fin': 0,
#    'lucrative': 0,
#    'binary': 0,
#    'periphery': 0,
#    'apologised': 0,
#    'fixednthe': 0,
#    'updatesnthe': 0,
#    'celebrity': 0,
#    'undermines': 0,
#    'active': 0,
#    'devicesnthe': 0,
#    'memory': 0,
#    'strategically': 0,
#    'kitnhowever': 0,
#    'decryption': 0,
#    'suffered': 0,
#    'outcomesnfor': 0,
#    'unannounced': 0,
#    'banks': 0,
#    'servicesnsources': 0,
#    'forthcoming': 0,
#    'popular': 0,
#    'dont': 0,
#    'april': 0,
#    'managernduring': 0,
#    'disguising': 0,
#    'implementing': 0,
#    'u': 0,
#    'quietly': 0,
#    'overnight': 0,
#    'devicenthis': 0,
#    'entry': 0,
#    'attachment': 0,
#    'study': 0,
#    'utterly': 0,
#    'escape': 0,
#    'hackingnvulnerability': 0,
#    'versionna': 0,
#    'stuntman': 0,
#    'accountsnnnintendo': 0,
#    'improved': 0,
#    'brandnew': 0,
#    'craft': 0,
#    'infrastructure': 0,
#    'harnessing': 0,
#    'athletes': 0,
#    'carry': 0,
#    'open': 0,
#    'agencies': 0,
#    'bugsnsymantec': 0,
#    'aid': 0,
#    'beufreported': 0,
#    'viewing': 0,
#    'mysql': 0,
#    'pewdiepie': 0,
#    'earliernthe': 0,
#    'impersonate': 0,
#    'interfax': 0,
#    'status': 0,
#    'updated': 0,
#    'servicenthere': 0,
#    'respectively': 0,
#    'breachn': 0,
#    'publishes': 0,
#    'neglect': 0,
#    'finansowego': 0,
#    'komisja': 0,
#    'blockchain': 0,
#    'loss': 0,
#    'checkout': 0,
#    'prosecutors': 0,
#    'npassword': 0,
#    'notable': 0,
#    'generate': 0,
#    'lose': 0,
#    'fixesnany': 0,
#    'categorises': 0,
#    'detectionevasion': 0,
#    'ncscncryptomining': 0,
#    'controversynswedens': 0,
#    'exfiltration': 0,
#    'pleads': 0,
#    'circulating': 0,
#    'standardcompliant': 0,
#    'coldfusion': 0,
#    'beijingnmicrosoft': 0,
#    'launch': 0,
#    'indexed': 0,
#    'estimate': 0,
#    'perl': 0,
#    'neo': 0,
#    'gwr': 0,
#    'netlogon': 0,
#    'chancellor': 0,
#    'verification': 0,
#    'ecsepa': 0,
#    'ostensibly': 0,
#    'optimised': 0,
#    'rtf': 0,
#    'stressed': 0,
#    'numbersnthe': 0,
#    'safenchallenge': 0,
#    'affiliating': 0,
#    'delays': 0,
#    'italy': 0,
#    'possiblennthe': 0,
#    'recklessly': 0,
#    'subscription': 0,
#    'figuresnthe': 0,
#    'angus': 0,
#    'fixingnwhile': 0,
#    'apples': 0,
#    'nnthe': 0,
#    'outcome': 0,
#    'rescue': 0,
#    'roughly': 0,
#    'requestnimpersonation': 0,
#    'linknryuk': 0,
#    'port': 0,
#    'watchdog': 0,
#    'california': 0,
#    'sophistication': 0,
#    'poland': 0,
#    'large': 0,
#    'graphic': 0,
#    'jailed': 0,
#    'tested': 0,
#    'exfiltrated': 0,
#    'setup': 0,
#    'area': 0,
#    'respondents': 0,
#    'worryingly': 0,
#    'internetenabled': 0,
#    'gates': 0,
#    'frozen': 0,
#    'consequence': 0,
#    'websites': 0,
#    'sentry': 0,
#    'practice': 0,
#    'cycon': 0,
#    'nthese': 0,
#    'ot': 0,
#    'photocopiers': 0,
#    'type': 0,
#    'leverages': 0,
#    'operationsnthe': 0,
#    'nwhile': 0,
#    'helpfully': 0,
#    'outsourcing': 0,
#    'tool': 0,
#    'space': 0,
#    'combinedninsurers': 0,
#    'prioritynthe': 0,
#    'wed': 0,
#    'generation': 0,
#    'sort': 0,
#    'yearna': 0,
#    'theyre': 0,
#    'capability': 0,
#    'prompt': 0,
#    'nthis': 0,
#    'civil': 0,
#    'world': 0,
#    'purposesnthe': 0,
#    'contracts': 0,
#    'emergence': 0,
#    'government': 0,
#    'centrenfebruary': 0,
#    'pandemicnhowever': 0,
#    'boarding': 0,
#    'postnthe': 0,
#    'file': 0,
#    'cyberuk': 0,
#    'activitynmalware': 0,
#    'deliberate': 0,
#    'result': 0,
#    'spam': 0,
#    'reminder': 0,
#    'indeed': 0,
#    'martin': 0,
#    'empowering': 0,
#    'overlord': 0,
#    'containing': 0,
#    'stored': 0,
#    'graham': 0,
#    'responsenragnar': 0,
#    'lowquality': 0,
#    'controllers': 0,
#    'sheraton': 0,
#    'figures': 0,
#    'reparationnorganisations': 0,
#    'authored': 0,
#    'compromisena': 0,
#    'grow': 0,
#    'jpeg': 0,
#    'thing': 0,
#    'onlinenadvice': 0,
#    'pdf': 0,
#    'traditional': 0,
#    'minimum': 0,
#    'discovery': 0,
#    'start': 0,
#    'collect': 0,
#    'disruptionnthe': 0,
#    'microsoft': 0,
#    'domains': 0,
#    'singlesign': 0,
#    'personal': 0,
#    'conducing': 0,
#    'scheme': 0,
#    'confiscated': 0,
#    'newernthe': 0,
#    'unavailable': 0,
#    'mexicos': 0,
#    'ndigital': 0,
#    'socially': 0,
#    'icedovethunderbird': 0,
#    'exchange': 0,
#    'cited': 0,
#    'highlights': 0,
#    'informationnan': 0,
#    'bundled': 0,
#    'taiwanbased': 0,
#    'malware': 0,
#    'anticipate': 0,
#    'attackednon': 0,
#    'sporting': 0,
#    'content': 0,
#    'holidays': 0,
#    'happening': 0,
#    'tvnus': 0,
#    'qbot': 0,
#    'sums': 0,
#    'agencyufencourages': 0,
#    'sticks': 0,
#    'exciting': 0,
#    'deleting': 0,
#    'interests': 0,
#    'prepare': 0,
#    'overview': 0,
#    'securitynequifax': 0,
#    'enterprise': 0,
#    'accountinternetcomputer': 0,
#    'travelling': 0,
#    'expired': 0,
#    'profited': 0,
#    'ceases': 0,
#    'intact': 0,
#    'purported': 0,
#    'enumeration': 0,
#    'federation': 0,
#    'subscribers': 0,
#    'bring': 0,
#    'opportunity': 0,
#    'accountsnadvice': 0,
#    'credit': 0,
#    'diseases': 0,
#    'unauthorized': 0,
#    'leaves': 0,
#    'failings': 0,
#    'equivalent': 0,
#    'screens': 0,
#    'inevitable': 0,
#    'deliveries': 0,
#    'sends': 0,
#    'attacksnover': 0,
#    'controllersnthere': 0,
#    'six': 0,
#    'crimesnthis': 0,
#    'harvesting': 0,
#    'pixelsnthere': 0,
#    'earliest': 0,
#    'threatsnthe': 0,
#    'trickbot': 0,
#    'confirm': 0,
#    'consumers': 0,
#    'stuffing': 0,
#    'ncriminals': 0,
#    'addressed': 0,
#    'analysis': 0,
#    'extreme': 0,
#    'emailsnaction': 0,
#    'discreet': 0,
#    'build': 0,
#    'spoofed': 0,
#    'vietnam': 0,
#    'panic': 0,
#    'phishingnnnew': 0,
#    'onlinenthe': 0,
#    'r': 0,
#    'wellmess': 0,
#    'frauds': 0,
#    'safeguardsnts': 0,
#    'highlight': 0,
#    'corruption': 0,
#    'running': 0,
#    'claimed': 0,
#    'reminds': 0,
#    'sitenmicrosoft': 0,
#    'regarding': 0,
#    'compromising': 0,
#    'impactncryptocurrencies': 0,
#    'reading': 0,
#    'zendesk': 0,
#    'immediatelynmore': 0,
#    'apply': 0,
#    'qemu': 0,
#    'estatenfurther': 0,
#    'localisation': 0,
#    'onto': 0,
#    'neven': 0,
#    'releasednwe': 0,
#    'executionnibm': 0,
#    'student': 0,
#    'year': 0,
#    'ombudsman': 0,
#    'thanks': 0,
#    'sensitive': 0,
#    'clinic': 0,
#    'fundamental': 0,
#    'credentialsnelsewhere': 0,
#    'buckets': 0,
#    'even': 0,
#    'evaluating': 0,
#    'swipe': 0,
#    'addressninterestingly': 0,
#    'introduction': 0,
#    'founded': 0,
#    'educations': 0,
#    'sectorsnthe': 0,
#    'ndnthe': 0,
#    'rises': 0,
#    'investigated': 0,
#    'nour': 0,
#    'squad': 0,
#    'record': 0,
#    'callsnthe': 0,
#    'well': 0,
#    'yearround': 0,
#    'theftnuscert': 0,
#    'aims': 0,
#    'creates': 0,
#    'standard': 0,
#    'chineseaffiliated': 0,
#    'recommended': 0,
#    'scamsnnphishing': 0,
#    'identifiedndue': 0,
#    'commitment': 0,
#    'attempting': 0,
#    'everyday': 0,
#    'meltdown': 0,
#    'checked': 0,
#    'style': 0,
#    'customersnantitheft': 0,
#    'requests': 0,
#    'brand': 0,
#    'thisnwhile': 0,
#    'usdnfeibs': 0,
#    'remained': 0,
#    'store': 0,
#    'unfixed': 0,
#    'gaining': 0,
#    'underwent': 0,
#    'judgement': 0,
#    'remerged': 0,
#    'scale': 0,
#    'practicablenas': 0,
#    'movementsnfrom': 0,
#    'rnwindows': 0,
#    'acknowledging': 0,
#    'selectednyou': 0,
#    'change': 0,
#    'enhance': 0,
#    'zdnet': 0,
#    'guidensmall': 0,
#    'mail': 0,
#    'review': 0,
#    'attacknthe': 0,
#    'establishment': 0,
#    'pwc': 0,
#    'understood': 0,
#    'litigation': 0,
#    'engagement': 0,
#    'earned': 0,
#    'rafotecs': 0,
#    'seeking': 0,
# ...
#    'computer': 1,
#    'released': 1,
#    'devicesnphishing': 1,
#    'common': 1,
#    'diverted': 1,
#    'remains': 1,
#    'cyberfirst': 1,
#    'retraining': 1,
#    'published': 1,
#    'increase': 1,
#    'conferencing': 1,
#    'gaining': 1,
#    'home': 1,
#    'strongly': 1,
#    'career': 2,
#    'identified': 1,
#    'working': 2,
#    'employers': 1,
#    'businessesnthe': 1,
#    'reportnphishing': 1,
#    'business': 2,
#    'highlights': 1,
#    'confirmed': 1,
#    'februaryneach': 1,
#    'cases': 1,
#    'coronavirus': 1,
#    'effective': 1,
#    'sector': 1,
#    'staffnthe': 1,
#    'advanced': 1,
#    'organisation': 1,
#    'line': 1,
#    'large': 1,
#    'number': 2,
#    'alert': 3,
#    'remote': 1,
#    'incidents': 2,
#    'targeting': 1,
#    'since': 1,
#    'caused': 1,
#    'shows': 3,
#    'vulnerabilities': 1,
#    'last': 3,
#    'march': 1,
#    'threat': 1,
#    'multiple': 1,
#    'also': 5,
#    'experienced': 1,
#    'affected': 1,
#    'dcms': 1,
#    'risk': 1,
#    'configurationsnvpn': 1,
#    'vectors': 1,
#    'attacked': 1,
#    'address': 1,
#    'almost': 1,
#    'urging': 1,
#    'environments': 1,
#    'related': 1,
#    'urge': 0,
#    'herenformer': 0,
#    'industriesnthe': 0,
#    'settings': 0,
#    'forensic': 0,
#    'policymaking': 0,
#    'reviews': 0,
#    'securenfrom': 0,
#    'issues': 0,
#    'fbis': 0,
#    'usefulndefending': 0,
#    'hat': 0,
#    'servicenthe': 0,
#    'agreement': 0,
#    'chip': 0,
#    'bruteforce': 0,
#    'strobe': 0,
#    'limitations': 0,
#    'msn': 0,
#    'statement': 0,
#    'storage': 0,
#    'illegitimately': 0,
#    'magecarts': 0,
#    'capitalise': 0,
#    'obsolete': 0,
#    'filed': 0,
#    'sweden': 0,
#    'right': 0,
#    'hns': 0,
#    'increasensocial': 0,
#    'notifications': 0,
#    'permissions': 0,
#    'distributes': 0,
#    'nany': 0,
#    'conductednindia': 0,
#    'workaround': 0,
#    'worrying': 0,
#    'depend': 0,
#    'discountnearlier': 0,
#    'asavie': 0,
#    'devicesnhns': 0,
#    'concernsnretailer': 0,
#    'whereby': 0,
#    'taking': 0,
#    'passed': 0,
#    'fin': 0,
#    'lucrative': 0,
#    'binary': 0,
#    'periphery': 0,
#    'apologised': 0,
#    'fixednthe': 0,
#    'updatesnthe': 0,
#    'celebrity': 0,
#    'undermines': 0,
#    'active': 0,
#    'devicesnthe': 0,
#    'memory': 0,
#    'strategically': 0,
#    'kitnhowever': 0,
#    'decryption': 0,
#    'outcomesnfor': 0,
#    'unannounced': 0,
#    'banks': 0,
#    'servicesnsources': 0,
#    'forthcoming': 0,
#    'popular': 0,
#    'dont': 0,
#    'april': 0,
#    'managernduring': 0,
#    'disguising': 0,
#    'implementing': 0,
#    'u': 0,
#    'quietly': 0,
#    'overnight': 0,
#    'devicenthis': 0,
#    'entry': 0,
#    'attachment': 0,
#    'study': 0,
#    'utterly': 0,
#    'escape': 0,
#    'hackingnvulnerability': 0,
#    'versionna': 0,
#    'stuntman': 0,
#    'accountsnnnintendo': 0,
#    'improved': 0,
#    'brandnew': 0,
#    'craft': 0,
#    'infrastructure': 0,
#    'harnessing': 0,
#    'athletes': 0,
#    'carry': 0,
#    'open': 0,
#    'agencies': 0,
#    'bugsnsymantec': 0,
#    'aid': 0,
#    'beufreported': 0,
#    'viewing': 0,
#    'mysql': 0,
#    'pewdiepie': 0,
#    'earliernthe': 0,
#    'impersonate': 0,
#    'interfax': 0,
#    'status': 0,
#    'servicenthere': 0,
#    'respectively': 0,
#    'breachn': 0,
#    'publishes': 0,
#    'neglect': 0,
#    'finansowego': 0,
#    'komisja': 0,
#    'blockchain': 0,
#    'checkout': 0,
#    'prosecutors': 0,
#    'npassword': 0,
#    'notable': 0,
#    'generate': 0,
#    'lose': 0,
#    'fixesnany': 0,
#    'categorises': 0,
#    'detectionevasion': 0,
#    'ncscncryptomining': 0,
#    'controversynswedens': 0,
#    'exfiltration': 0,
#    'pleads': 0,
#    'circulating': 0,
#    'standardcompliant': 0,
#    'coldfusion': 0,
#    'beijingnmicrosoft': 0,
#    'launch': 0,
#    'indexed': 0,
#    'estimate': 0,
#    'perl': 0,
#    'neo': 0,
#    'gwr': 0,
#    'netlogon': 0,
#    'chancellor': 0,
#    'verification': 0,
#    'ecsepa': 0,
#    'ostensibly': 0,
#    'optimised': 0,
#    'rtf': 0,
#    'stressed': 0,
#    'numbersnthe': 0,
#    'safenchallenge': 0,
#    'affiliating': 0,
#    'delays': 0,
#    'italy': 0,
#    'possiblennthe': 0,
#    'recklessly': 0,
#    'subscription': 0,
#    'linkedin': 0,
#    'figuresnthe': 0,
#    'angus': 0,
#    'fixingnwhile': 0,
#    'apples': 0,
#    'nnthe': 0,
#    'outcome': 0,
#    'rescue': 0,
#    'roughly': 0,
#    'requestnimpersonation': 0,
#    'linknryuk': 0,
#    'port': 0,
#    'watchdog': 0,
#    'california': 0,
#    'sophistication': 0,
#    'poland': 0,
#    'graphic': 0,
#    'jailed': 0,
#    'tested': 0,
#    'exfiltrated': 0,
#    'setup': 0,
#    'area': 0,
#    'respondents': 0,
#    'worryingly': 0,
#    'internetenabled': 0,
#    'gates': 0,
#    'frozen': 0,
#    'consequence': 0,
#    'websites': 0,
#    'sentry': 0,
#    'practice': 0,
#    'cycon': 0,
#    'nthese': 0,
#    'ot': 0,
#    'photocopiers': 0,
#    'type': 0,
#    'leverages': 0,
#    'operationsnthe': 0,
#    'nwhile': 0,
#    'helpfully': 0,
#    'outsourcing': 0,
#    'tool': 0,
#    'space': 0,
#    'combinedninsurers': 0,
#    'prioritynthe': 0,
#    'wed': 0,
#    'generation': 0,
#    'sort': 0,
#    'yearna': 0,
#    'theyre': 0,
#    'capability': 0,
#    'prompt': 0,
#    'nthis': 0,
#    'civil': 0,
#    'world': 0,
#    'purposesnthe': 0,
#    'contracts': 0,
#    'emergence': 0,
#    'government': 0,
#    'centrenfebruary': 0,
#    'pandemicnhowever': 0,
#    'boarding': 0,
#    'postnthe': 0,
#    'file': 0,
#    'cyberuk': 0,
#    'activitynmalware': 0,
#    'deliberate': 0,
#    'result': 0,
#    'spam': 0,
#    'reminder': 0,
#    'indeed': 0,
#    'martin': 0,
#    'empowering': 0,
#    'overlord': 0,
#    'containing': 0,
#    'stored': 0,
#    'graham': 0,
#    'responsenragnar': 0,
#    'lowquality': 0,
#    'controllers': 0,
#    'sheraton': 0,
#    'figures': 0,
#    'reparationnorganisations': 0,
#    'authored': 0,
#    'compromisena': 0,
#    'grow': 0,
#    'jpeg': 0,
#    'thing': 0,
#    'onlinenadvice': 0,
#    'pdf': 0,
#    'traditional': 0,
#    'vulnerability': 0,
#    'minimum': 0,
#    'discovery': 0,
#    'start': 0,
#    'collect': 0,
#    'disruptionnthe': 0,
#    'domains': 0,
#    'singlesign': 0,
#    'personal': 0,
#    'conducing': 0,
#    'scheme': 0,
#    'confiscated': 0,
#    'newernthe': 0,
#    'unavailable': 0,
#    'mexicos': 0,
#    'ndigital': 0,
#    'socially': 0,
#    'icedovethunderbird': 0,
#    'cited': 0,
#    'informationnan': 0,
#    'bundled': 0,
#    'taiwanbased': 0,
#    'malware': 0,
#    'anticipate': 0,
#    'attackednon': 0,
#    'sporting': 0,
#    'content': 0,
#    'holidays': 0,
#    'happening': 0,
#    'tvnus': 0,
#    'qbot': 0,
#    'sums': 0,
#    'agencyufencourages': 0,
#    'sticks': 0,
#    'exciting': 0,
#    'deleting': 0,
#    'interests': 0,
#    'prepare': 0,
#    'overview': 0,
#    'securitynequifax': 0,
#    'enterprise': 0,
#    'accountinternetcomputer': 0,
#    'travelling': 0,
#    'expired': 0,
#    'profited': 0,
#    'ceases': 0,
#    'intact': 0,
#    'purported': 0,
#    'enumeration': 0,
#    'federation': 0,
#    'subscribers': 0,
#    'bring': 0,
#    'opportunity': 0,
#    'accountsnadvice': 0,
#    'credit': 0,
#    'diseases': 0,
#    'unauthorized': 0,
#    'leaves': 0,
#    'failings': 0,
#    'equivalent': 0,
#    'screens': 0,
#    'inevitable': 0,
#    'deliveries': 0,
#    'sends': 0,
#    'attacksnover': 0,
#    'controllersnthere': 0,
#    'six': 0,
#    'crimesnthis': 0,
#    'harvesting': 0,
#    'pixelsnthere': 0,
#    'earliest': 0,
#    'threatsnthe': 0,
#    'trickbot': 0,
#    'confirm': 0,
#    'consumers': 0,
#    'stuffing': 0,
#    'ncriminals': 0,
#    'addressed': 0,
#    'analysis': 0,
#    'extreme': 0,
#    'emailsnaction': 0,
#    'discreet': 0,
#    'build': 0,
#    'spoofed': 0,
#    'vietnam': 0,
#    'panic': 0,
#    'phishingnnnew': 0,
#    'onlinenthe': 0,
#    'r': 0,
#    'wellmess': 0,
#    'frauds': 0,
#    'safeguardsnts': 0,
#    'highlight': 0,
#    'corruption': 0,
#    'running': 0,
#    'claimed': 0,
#    'reminds': 0,
#    'sitenmicrosoft': 0,
#    'regarding': 0,
#    'compromising': 0,
#    'impactncryptocurrencies': 0,
#    'reading': 0,
#    'zendesk': 0,
#    'immediatelynmore': 0,
#    'apply': 0,
#    'qemu': 0,
#    'estatenfurther': 0,
#    'localisation': 0,
#    'onto': 0,
#    'neven': 0,
#    'releasednwe': 0,
#    'executionnibm': 0,
#    'ombudsman': 0,
#    'thanks': 0,
#    'groups': 0,
#    'sensitive': 0,
#    'clinic': 0,
#    'fundamental': 0,
#    'credentialsnelsewhere': 0,
#    'buckets': 0,
#    'even': 0,
#    'evaluating': 0,
#    'swipe': 0,
#    'addressninterestingly': 0,
#    'introduction': 0,
#    'founded': 0,
#    'educations': 0,
#    'sectorsnthe': 0,
#    'ndnthe': 0,
#    'investigated': 0,
#    'nour': 0,
#    'squad': 0,
#    'record': 0,
#    'callsnthe': 0,
#    'well': 0,
#    'yearround': 0,
#    'theftnuscert': 0,
#    'aims': 0,
#    'creates': 0,
#    'standard': 0,
#    'chineseaffiliated': 0,
#    'recommended': 0,
#    'scamsnnphishing': 0,
#    'identifiedndue': 0,
#    'commitment': 0,
#    'attempting': 0,
#    'everyday': 0,
#    'meltdown': 0,
#    'checked': 0,
#    'style': 0,
#    'customersnantitheft': 0,
#    'requests': 0,
#    'brand': 0,
#    'thisnwhile': 0,
#    'usdnfeibs': 0,
#    'store': 0,
#    'unfixed': 0,
#    'underwent': 0,
#    'judgement': 0,
#    'remerged': 0,
#    'scale': 0,
#    'practicablenas': 0,
#    'movementsnfrom': 0,
#    'rnwindows': 0,
#    'acknowledging': 0,
#    'selectednyou': 0,
#    'change': 0,
#    'enhance': 0,
#    'zdnet': 0,
#    'guidensmall': 0,
#    'mail': 0,
#    'review': 0,
#    'attacknthe': 0,
#    'establishment': 0,
#    'pwc': 0,
#    'understood': 0,
#    'litigation': 0,
#    'engagement': 0,
#    'earned': 0,
#    'rafotecs': 0,
#    'seeking': 0,
#    'pandemicnnthe': 0,
#    'coronavirusrelated': 0,
#    'cybereason': 0,
#    'investors': 0,
#    'toyotas': 0,
#    'roughtedrelated': 0,
#    'managed': 0,
#    'commissioner': 0,
#    'blaming': 0,
#    'terabits': 0,
#    'smb': 0,
#    'vulnerabilitynthe': 0,
#    'adclick': 0,
#    'insiders': 0,
#    'exercise': 0,
#    'surname': 0,
#    'obligations': 0,
#    'newcastle': 0,
#    'cease': 0,
#    'offers': 0,
#    'attacksnif': 0,
#    'restrictions': 0,
#    'rising': 0,
#    'olympic': 0,
#    'wpa': 0,
#    'completely': 0,
#    'informatica': 0,
#    'innby': 0,
#    'emailing': 0,
#    'theyd': 0,
#    'infectionnvulnerabilitiesnthis': 0,
#    'collapse': 0,
#    'malaysia': 0,
#    'studentsnmedia': 0,
#    'cryptocurrencynthe': 0,
#    'acknowledge': 0,
#    'passwordsnvulnerabilitiesnthere': 0,
#    'chats': 0,
#    'phased': 0,
#    'onlinenyou': 0,
#    'hope': 0,
#    'hijacks': 0,
#    'daynused': 0,
#    'moneymotivated': 0,
#    'great': 0,
#    'attacknyou': 0,
#    'androidncisco': 0,
#    'quieter': 0,
#    'gadgets': 0,
#    'caribbean': 0,
#    'mostly': 0,
#    'buffer': 0,
#    'push': 0,
#    'finland': 0,
#    'sshaikhcoventryacuk': 0,
#    'festive': 0,
#    'periodicallynthis': 0,
#    'chris': 0,
#    'servicesnon': 0,
#    'seekna': 0,
#    'imgur': 0,
#    'attacknwe': 0,
#    'opening': 0,
#    'blognswedish': 0,
#    'undercutting': 0,
#    'conscious': 0,
#    'beta': 0,
#    'nandroid': 0,
#    'feasible': 0,
#    'iranian': 0,
#    'browse': 0,
#    'vulnerabilitynsecurity': 0,
#    'cashing': 0,
#    'crafting': 0,
#    'mere': 0,
#    'promote': 0,
#    'labsnit': 0,
#    'giftsnadvice': 0,
#    'gathered': 0,
#    'surveillance': 0,
#    'pwned': 0,
#    'design': 0,
#    'examplesnthe': 0,
#    'paymentnphishing': 0,
#    'zealand': 0,
#    'measurement': 0,
#    'lowest': 0,
#    'ian': 0,
#    'sectors': 0,
#    'clear': 0,
#    'started': 0,
#    'devicenkeep': 0,
#    'established': 0,
#    'proofpoints': 0,
#    'impossible': 0,
#    'measuring': 0,
#    'lie': 0,
#    'cvensap': 0,
#    'networksnukrainian': 0,
#    'fraudsters': 0,
#    'ncustomers': 0,
#    'productsnthe': 0,
#    'slowdown': 0,
#    'universal': 0,
#    'shipping': 0,
#    'misconfiguration': 0,
#    'specialists': 0,
#    'purposesnmalware': 0,
#    'logger': 0,
#    'possibility': 0,
#    'resource': 0,
#    'transportstyrelsen': 0,
#    'pertain': 0,
#    'outsourced': 0,
#    'allnmeanwhile': 0,
#    'hitting': 0,
#    'nresearchers': 0,
#    'webnan': 0,
#    'adapted': 0,
#    'backdoors': 0,
#    'index': 0,
#    'expertsna': 0,
#    'adjust': 0,
#    'youtube': 0,
#    'f': 0,
#    'previously': 0,
#    'recordings': 0,
#    'forhire': 0,
#    'parliament': 0,
#    'performing': 0,
#    'activated': 0,
#    'trustbased': 0,
#    'infect': 0,
#    'enabler': 0,
#    'schneider': 0,
#    'cent': 0,
#    'pull': 0,
#    'skimmer': 0,
#    'govuk': 0,
#    'concernednthis': 0,
#    'futurenweve': 0,
#    'downloadable': 0,
#    'quora': 0,
#    'presidential': 0,
#    'guidancenelection': 0,
#    'sporadically': 0,
#    'nonstate': 0,
#    'warnings': 0,
#    'apart': 0,
#    'qualifications': 0,
#    'produce': 0,
#    'reportedly': 0,
#    'residents': 0,
#    'industrynthis': 0,
#    'bn': 0,
#    'landscape': 0,
#    'heavily': 0,
#    'vbucks': 0,
#    'improve': 0,
#    'againnit': 0,
#    'yet': 0,
#    'responses': 0,
#    'results': 0,
#    'pain': 0,
#    'authenticity': 0,
#    'unaware': 0,
#    'themnmixing': 0,
#    'weve': 0,
#    'announced': 0,
#    'know': 0,
#    'websitenvulnerabilitiesnthere': 0,
#    'continued': 0,
#    'analyse': 0,
#    'websitenvmware': 0,
#    'christmas': 0,
#    'wiskunde': 0,
#    'findnin': 0,
#    'sets': 0,
#    'intermittent': 0,
#    'sourcendata': 0,
#    'softwaredefined': 0,
#    'behaviour': 0,
#    'apple': 0,
#    'sometimes': 0,
#    'bargain': 0,
#    'collective': 0,
#    'prosecution': 0,
#    'nxos': 0,
#    'serves': 0,
#    'collectionnaccording': 0,
#    'intrusion': 0,
#    'reproducing': 0,
#    'swift': 0,
#    'excess': 0,
#    'securities': 0,
#    'wwwactionfraudpoliceuk': 0,
#    'august': 0,
#    'eg': 0,
#    'clicked': 0,
#    'publishing': 0,
#    'knf': 0,
#    'extent': 0,
#    'protections': 0,
#    'household': 0,
#    'prevents': 0,
#    'posit': 0,
#    'virtualboxnelsewhere': 0,
#    'leitschuh': 0,
#    'responded': 0,
#    'removednnumber': 0,
#    'cryptographic': 0,
#    'traps': 0,
#    'accompanied': 0,
#    'thisnwith': 0,
#    'non': 0,
#    'letter': 0,
#    'unpaired': 0,
#    'disappointed': 0,
#    'passwordstuffing': 0,
#    'neutralises': 0,
#    'suited': 0,
#    'eventual': 0,
#    'flashpoint': 0,
#    'strengthens': 0,
#    'cardnonline': 0,
#    'terms': 0,
#    'directly': 0,
#    'dharma': 0,
#    'itngranting': 0,
#    'enabled': 0,
#    'scammer': 0,
#    'luck': 0,
#    'serious': 0,
#    'googles': 0,
#    'vector': 0,
#    'popularnaccording': 0,
#    'spent': 0,
#    'tackling': 0,
#    'choices': 0,
#    'internetna': 0,
#    'gwrcom': 0,
#    'patchnas': 0,
#    'incidentsnweve': 0,
#    'metronbad': 0,
#    'doj': 0,
#    'gigabits': 0,
#    'devicesncomrat': 0,
#    'repetitive': 0,
#    'roughted': 0,
#    'duplicatesnsms': 0,
#    'detectionnsowburgs': 0,
#    'unspecified': 0,
#    'companies': 0,
#    'ring': 0,
#    'resilience': 0,
#    'analytics': 0,
#    'flawsnthe': 0,
#    'life': 0,
#    'newbie': 0,
#    'bulk': 0,
#    'numbersntiktoks': 0,
#    'terrorist': 0,
#    'providersna': 0,
#    'validation': 0,
#    'bar': 0,
#    'paralympic': 0,
#    'nessus': 0,
#    'background': 0,
#    'germanys': 0,
#    'makers': 0,
#    'highprofile': 0,
#    'compromisenidentifying': 0,
#    'services': 0,
#    'searches': 0,
#    'innocuous': 0,
#    'pnrnresearchers': 0,
#    'obtainedndisgruntled': 0,
#    'eventually': 0,
#    'hall': 0,
#    'bills': 0,
#    'manufacture': 0,
#    'signing': 0,
#    'cyberexposure': 0,
#    'leasing': 0,
#    'thinks': 0,
#    'mmo': 0,
#    'existed': 0,
#    'intended': 0,
#    'zeroday': 0,
#    'backups': 0,
#    'servicesnsome': 0,
#    'versionsnmicrosoft': 0,
#    'bodybuildingcom': 0,
#    'dupe': 0,
#    'internetnrecent': 0,
#    'deployed': 0,
#    'flexibility': 0,
#    'submitted': 0,
#    'redcar': 0,
#    'patchednorganisations': 0,
#    'election': 0,
#    'view': 0,
#    'asia': 0,
#    'aggressively': 0,
#    'portions': 0,
#    'licence': 0,
#    'administer': 0,
#    'disgruntled': 0,
#    'standards': 0,
#    'context': 0,
#    'messagesntrue': 0,
#    'filters': 0,
#    'journalists': 0,
#    'sri': 0,
#    'usernames': 0,
#    'accountsnafter': 0,
#    'gave': 0,
#    'varies': 0,
#    'toysnthe': 0,
#    'stickers': 0,
#    'cvv': 0,
#    'scheduled': 0,
#    'pocketnaccording': 0,
#    'driver': 0,
#    'reloadnin': 0,
#    'mobilebased': 0,
#    'super': 0,
#    'accountability': 0,
#    'paul': 0,
#    'fraudnthe': 0,
#    'saved': 0,
#    'ensure': 0,
#    'little': 0,
#    'payloadnavasts': 0,
#    'majesty': 0,
#    'reused': 0,
#    'guilty': 0,
#    'agent': 0,
#    'refers': 0,
#    'fbiufissued': 0,
#    'februarynsha': 0,
#    'jailedna': 0,
#    'relies': 0,
#    'cleaner': 0,
#    'channel': 0,
#    'power': 0,
#    'times': 0,
#    'full': 0,
#    'rnall': 0,
#    'herena': 0,
#    'ubers': 0,
#    'centres': 0,
#    'responding': 0,
#    'ownership': 0,
#    'easier': 0,
#    'compliance': 0,
#    'exposedntwitter': 0,
#    'challengesnpasswords': 0,
#    'trash': 0,
#    'upcoming': 0,
#    'probably': 0,
#    'smallest': 0,
#    'soufthe': 0,
#    'heighten': 0,
#    'removes': 0,
#    'conclusion': 0,
#    ...})]

# %%
df_hur = sparknlp.parallelize(word_count.items()).toDF(['word', 'count'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-cc10f22d1c2e> in <module>
# ----> 1 df_hur = sparknlp.parallelize(word_count.items()).toDF(['word', 'count'])
#
# AttributeError: 'SparkSession' object has no attribute 'parallelize'
